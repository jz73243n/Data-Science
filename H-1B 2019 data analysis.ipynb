# %%
# setup coding environment 


import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['h1b_datahubexport-2019.csv']

# %%
#read file
df = pd.read_csv('../input/h1b_datahubexport-2019.csv')

# %%
#check info, head, describe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22501 entries, 0 to 22500
# Data columns (total 11 columns):
# Fiscal Year             22501 non-null int64
# Employer                22500 non-null object
# Initial Approvals       22501 non-null int64
# Initial Denials         22501 non-null int64
# Continuing Approvals    22501 non-null int64
# Continuing Denials      22501 non-null int64
# NAICS                   22501 non-null int64
# Tax ID                  22466 non-null float64
# State                   22500 non-null object
# City                    22501 non-null object
# ZIP                     22500 non-null float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#        Fiscal Year  Initial Approvals      ...             Tax ID           ZIP
# count      22501.0       22501.000000      ...       22466.000000  22500.000000
# mean        2019.0           1.482867      ...        4939.133891  47760.174622
# std            0.0          12.238135      ...        2885.869758  33952.452122
# min         2019.0           0.000000      ...           1.000000    738.000000
# 25%         2019.0           0.000000      ...        2444.000000  11372.000000
# 50%         2019.0           1.000000      ...        4926.000000  45242.000000
# 75%         2019.0           1.000000      ...        7410.000000  80021.000000
# max         2019.0        1177.000000      ...        9999.000000  99801.000000
#
# [8 rows x 8 columns]

# %%
df.head(10)
# Out:
#    Fiscal Year   ...         ZIP
# 0         2019   ...     35233.0
# 1         2019   ...     91007.0
# 2         2019   ...     90221.0
# 3         2019   ...     90034.0
# 4         2019   ...     80301.0
# 5         2019   ...      6880.0
# 6         2019   ...     33178.0
# 7         2019   ...     32258.0
# 8         2019   ...     30005.0
# 9         2019   ...     60108.0
#
# [10 rows x 11 columns]

# %%
df['Employer'].nunique()
# Out:
# 21085

# %%
#convert Fiscal Year to datetime
df['Fiscal Year'] = pd.to_datetime(df['Fiscal Year'])

# %%
#check top approval company
df[df['Initial Approvals'] == df['Initial Approvals'].max()]
# Out:
#                         Fiscal Year   ...         ZIP
# 22394 1970-01-01 00:00:00.000002019   ...     20850.0
#
# [1 rows x 11 columns]

# %%
#check top denial company
df[df['Initial Denials'] == df['Initial Denials'].max()]
# Out:
#                         Fiscal Year   ...         ZIP
# 22394 1970-01-01 00:00:00.000002019   ...     20850.0
#
# [1 rows x 11 columns]

# %%
#number of approvals
print(df['Initial Approvals'].sum())
print(df['Continuing Approvals'].sum())
print(df['Initial Approvals'].sum() + df['Continuing Approvals'].sum())
# Out:
# 33366
# 43268
# 76634

# %%
#create new column
df['total_approval'] = df['Initial Approvals'] + df['Continuing Approvals']

# %%
#check top employers info
byEmployer = df.groupby('Employer').sum()
byEmployer.sort_values('Initial Approvals', ascending=False)
# Out:
#                                    Initial Approvals       ...        total_approval
# Employer                                                   ...
# TATA CONSULTANCY SVCS LTD                       1185       ...                  3069
# AMAZON.COM SERVICES INC                          607       ...                   731
# GOOGLE LLC                                       526       ...                   767
# TECH MAHINDRA AMERICAS INC                       478       ...                  1021
# DELOITTE CONSULTING LLP                          425       ...                  1672
# MICROSOFT CORPORATION                            367       ...                   852
# FACEBOOK INC                                     353       ...                   452
# LARSEN AND TOUBRO INFOTECH LTD                   317       ...                   734
# WIPRO LIMITED                                    271       ...                   925
# MPHASIS CORPORATION                              222       ...                   440
# INTEL CORPORATION                                216       ...                   331
# QUALCOMM TECHNOLOGIES INC                        208       ...                   234
# APPLE INC                                        195       ...                   432
# IBM CORPORATION                                  162       ...                   244
# COGNIZANT TECH SOLNS US CORP                     159       ...                  1877
# CAPGEMINI AMERICA INC                            156       ...                   662
# PRICEWATERHOUSECOOPERS LLP                       133       ...                   195
# CISCO SYSTEMS INC                                119       ...                   321
# TESLA INC                                        117       ...                   143
# HEXAWARE TECHNOLOGIES INC                        116       ...                   258
# CERNER CORPORATION                               113       ...                   143
# ACCENTURE LLP                                    102       ...                   573
# ORACLE AMERICA INC                               100       ...                   276
# JPMORGAN CHASE & CO                               96       ...                   307
# SAP AMERICA INC                                   88       ...                   137
# UBER TECHNOLOGIES INC                             86       ...                   133
# ERNST & YOUNG US LLP                              83       ...                   711
# VIRTUSA CORPORATION                               82       ...                   278
# MCKINSEY & COMPANY INC US                         82       ...                   118
# EBAY INC                                          80       ...                   145
# ...                                              ...       ...                   ...
# ISAAC SCHOOL DISTRICT 5                            0       ...                     2
# ISEE YOUCARE INC                                   0       ...                     0
# ISEEBELL INC                                       0       ...                     0
# IORMYX INC                                         0       ...                     1
# IONIDEA INC                                        0       ...                     1
# INTL TECH INDUSTRY LEAGUE INC                      0       ...                     1
# INVAGEN PHARMACEUTICALS INC                        0       ...                     4
# INTL TECHS PRO DBA IQ TECH PROS                    0       ...                     0
# INTL UNION AGAINST TUBERCULOSIS &                  0       ...                     1
# INTL VITAMIN CORPORATION                           0       ...                     1
# INTREPID CONTROL SYSTEMS INC                       0       ...                     0
# INTROLLIGENT INC                                   0       ...                     2
# INTUEOR CONSULTING, INC.                           0       ...                     1
# INTUITES LLC                                       0       ...                     0
# INTUNE SYSTEMS INC                                 0       ...                     1
# INTUS WINDOWS LLC                                  0       ...                     1
# INUTEQ LLC                                         0       ...                     0
# INVENIO BUSINESS SOLUTIONS INC                     0       ...                     0
# IONA COLLEGE                                       0       ...                     2
# INVENSYS INC                                       0       ...                     3
# INVENTA GROUP INC                                  0       ...                     1
# INVENTIONS INC                                     0       ...                     2
# INVESTIGATIVE POST INC                             0       ...                     1
# INVICKTUS INC                                      0       ...                     1
# INVICTUS INFOTECH LLC                              0       ...                     4
# IO DATASPERE INC                                   0       ...                     1
# IOLAP INC                                          0       ...                     1
# IOLITEC IONIC LIQUIDS TECH INC                     0       ...                     0
# IOMEGA TECHNOLOGIES INC                            0       ...                     4
# LAP PETROLEUM LLC                                  0       ...                     1
#
# [21085 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Fiscal Year', 'Employer', 'Initial Approvals', 'Initial Denials',
#        'Continuing Approvals', 'Continuing Denials', 'NAICS', 'Tax ID',
#        'State', 'City', 'ZIP', 'total_approval'],
#       dtype='object')

# %%
#new dataframe with only two columns
new = pd.DataFrame(df.drop(['Fiscal Year', 'Employer', 'Initial Denials',
       'Continuing Approvals', 'Continuing Denials', 'NAICS', 'Tax ID', 'City', 'ZIP','total_approval'], axis=1))

# %%
byState = new.groupby('State').sum().sort_values('Initial Approvals', ascending=False).reset_index()
final = pd.DataFrame(byState)
final
# Out:
#    State  Initial Approvals
# 0     CA               7277
# 1     NJ               3932
# 2     TX               2845
# 3     NY               2705
# 4     MA               1760
# 5     MD               1664
# 6     WA               1485
# 7     IL               1468
# 8     VA               1174
# 9     PA               1103
# 10    MI               1098
# 11    FL                898
# 12    GA                741
# 13    NC                687
# 14    AZ                509
# 15    OH                430
# 16    CT                360
# 17    MN                345
# 18    MO                342
# 19    TN                276
# 20    CO                232
# 21    WI                197
# 22    IN                189
# 23    DC                137
# 24    DE                127
# 25    IA                122
# 26    NE                122
# 27    UT                113
# 28    OR                 90
# 29    KS                 88
# 30    ID                 75
# 31    KY                 69
# 32    AL                 67
# 33    AR                 66
# 34    SC                 63
# 35    RI                 62
# 36    OK                 54
# 37    LA                 54
# 38    NM                 53
# 39    NV                 50
# 40    NH                 43
# 41    MS                 33
# 42    HI                 28
# 43    ME                 24
# 44    WV                 21
# 45    ND                 20
# 46    SD                 17
# 47    VT                 13
# 48    GU                  8
# 49    PR                  8
# 50    AK                  6
# 51    MT                  6
# 52    WY                  5
# 53    MP                  4
# 54    VI                  0

# %%
final['Initial Approvals'].sum()
# Out:
# 33365

# %%
#plot the total_approval
fig, ax = plt.subplots(figsize=(15,5))

sns.barplot(x='State', y='Initial Approvals', data=final, palette='Set2')
plt.tight_layout()

# %%
df.columns
# Out:
# Index(['Fiscal Year', 'Employer', 'Initial Approvals', 'Initial Denials',
#        'Continuing Approvals', 'Continuing Denials', 'NAICS', 'Tax ID',
#        'State', 'City', 'ZIP', 'total_approval'],
#       dtype='object')

# %%
sns.lmplot(x='Initial Approvals', y='Continuing Approvals', data=df)
plt.tight_layout()
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
sns.jointplot(x='Initial Approvals', y='Continuing Approvals', data=df)
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
